# %%
datasets = {
    "ArticularyWordRecognition": "https://www.timeseriesclassification.com/aeon-toolkit/ArticularyWordRecognition.zip",
    "AtrialFibrillation": "https://www.timeseriesclassification.com/aeon-toolkit/AtrialFibrillation.zip",
    "BasicMotions": "https://www.timeseriesclassification.com/aeon-toolkit/BasicMotions.zip",
    "Cricket": "https://www.timeseriesclassification.com/aeon-toolkit/Cricket.zip",
    # "DuckDuckGeese": "https://www.timeseriesclassification.com/aeon-toolkit/DuckDuckGeese.zip",
    # "EigenWorms": "https://www.timeseriesclassification.com/aeon-toolkit/EigenWorms.zip",
    "Epilepsy": "https://www.timeseriesclassification.com/aeon-toolkit/Epilepsy.zip",
    # "EthanolConcentration": "https://www.timeseriesclassification.com/aeon-toolkit/EthanolConcentration.zip",
    "ERing": "https://www.timeseriesclassification.com/aeon-toolkit/ERing.zip",
    # "FaceDetection": "https://www.timeseriesclassification.com/aeon-toolkit/FaceDetection.zip",
}

# %%
from benchmark import benchmark

benchmark(datasets, 100)
# Out:
# 2025-02-27 10:42:23 URL:https://www.timeseriesclassification.com/aeon-toolkit/ArticularyWordRecognition.zip [7227737/7227737] -> "datasets/ArticularyWordRecognition/data.zip" [1]
# [I 2025-02-27 10:42:23,980] A new study created in memory with name: no-name-f6f35eb2-1206-4af9-bcce-5d1637dc671c
# Downloaded ArticularyWordRecognition
# [W 2025-02-27 10:43:25,093] Trial 0 failed with parameters: {'alpha': 0.32530430917290865, 'R0': 0.2952301420676277, 'R1': 0.3969460472345701, 'R2': 0.1906021190253347, 'R3': 0.21957892710682556, 'R4': 0.02647132023701183, 'R5': 0.25791172398043016, 'R6': 0.26203369449502595, 'R7': 0.14680318771726794, 'R8': 0.2916763551950452, 'bad_th': 0.08732342366323725} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/ciel/lib/python3.11/site-packages/optuna/study/_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
# ...
